# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
import WazeRouteCalculator
import datetime

# %% [markdown]
# ## Pulling Job Data

# %%
#project_path = "/Users/jjespinoza/GoogleDrive/2_projects/2_itsfriday/"
project_path = "/home/jj_espinoza_la/itsfriday/"

now = datetime.datetime.now()
now.year
now.month
now.day
date = str(now.year) + str(now.month) + str(now.day) + "_" + str(now.hour) + str(now.minute)
date
# Out:
# '2018121_1829'

# %%
max_results_per_city = 1
max_commute = 45
#city_set = ['Los+Angeles']
city_set = ['Los+Angeles', 'Los+Angeles+County', 'Long+Beach', 'Downey', 'Commerce', 'El+Segundo']
#title_set = ['data+scientist']
title_set = ['data+scientist', 'senior+data+scientist', 'director+data+science', 'director+analytics', 'vice+president+analytics', 'vice+president+data+science']
columns = ['city', 'job_title', 'company_name', 'location', 'summary', 'salary']
sample_df = pd.DataFrame(columns = columns)

# %%
#scraping code:
for title in title_set:
    for city in city_set:
        for start in range(0, max_results_per_city, 10):
            page = requests.get('http://www.indeed.com/jobs?q='+ str(title) +'+%2420%2C000&l=' + str(city) + '&start=' + str(start))
            time.sleep(1)  #ensuring at least 1 second between page grabs
            soup = BeautifulSoup(page.text, 'lxml')
            for div in soup.find_all(name='div', attrs={'class':'row'}): 
                #specifying row num for index of job posting in dataframe
                num = (len(sample_df) + 1) 
                
                #creating an empty list to hold the data for each posting
                job_post = [] 
                #append city name
                job_post.append(city) 
                
                #grabbing job title
                for a in div.find_all(name='a', attrs={'data-tn-element':'jobTitle'}):
                    job_post.append(a['title']) 
                
                #grabbing company name
                company = div.find_all(name='span', attrs={'class':'company'}) 
                if len(company) > 0: 
                    for b in company:
                        job_post.append(b.text.strip()) 
                else: 
                    sec_try = div.find_all(name='span', attrs={'class':'result-link-source'})
                    for span in sec_try:
                        job_post.append(span.text) 
                
                #grabbing location name
                c = div.findAll('span', attrs={'class': 'location'}) 
                for span in c: 
                    job_post.append(span.text) 
                
                #grabbing summary text
                d = div.findAll('span', attrs={'class': 'summary'}) 
                for span in d:
                    job_post.append(span.text.strip()) 
                
                #grabbing salary
                try:
                    job_post.append(div.find('nobr').text) 
                except:
                    try:
                        div_two = div.find(name='div', attrs={'class':'sjcl'}) 
                        div_three = div_two.find('div') 
                        job_post.append(div_three.text.strip())
                    except:
                        job_post.append('Nothing_found') 
                #appending list of job post info to dataframe at index num
                sample_df.loc[num] = job_post

# %%
del sample_df['city']

# %%
sample_df['job_title'] = sample_df['job_title'].str.lower()
sample_df['company_name'] = sample_df['company_name'].str.lower()
sample_df['location'] = sample_df['location'].str.lower()
sample_df['summary'] = sample_df['summary'].str.lower()
sample_df = sample_df.drop_duplicates(subset=['job_title', 'company_name'], keep = False)

# %% [markdown]
# ### Saving Raw Data

# %%
sample_df.to_csv(project_path + "2_data/1_raw/scraper_indeed_jobs_raw.csv", encoding='utf-8')
sample_df
# Out:
#                                              job_title  \
# 9                               data analyst - tableau
# 11                                      data scientist
# 12                                      data scientist
# 17                                      data scientist
# 18                     clinical lab research scientist
# 19   operational risk reporting and metrics specialist
# 26                                      data scientist
# 27                                     analyst - gamma
# 28                                      data scientist
# 30                            data analysis specialist
# 41                                      data scientist
# 42                             junior research analyst
# 44                    signal processing data scientist
# 49                       clinical laboratory scientist
# 65                         clinical research scientist
# 69                          marketing research analyst
# 94                               senior data scientist
# 95           cosc customer operations support engineer
# 105                                 sr. data scientist
# 106                   senior data engineer / architect
# 117                              senior data scientist
# 118  senior data scientist - informational intellig...
# 119                              data scientist senior
# 162  senior manager / director, product management ...
# 175                         health data project leader
# 191  senior healthcare economics consultant (remote...
# 193                                 analytics director
# 211                   director, information technology
# 216           director of permanent supportive housing
# 222        dean, office of institutional effectiveness
# 232                         director, people analytics
# 245                              director of analytics
# 269              executive director, quality analytics
# 271       director of healthcare economics & analytics
# 294                                      director of e
# 300                       director of growth marketing
# 310       vice president of sales, sports sponsorships
# 329                                       vp marketing
# 330                       vp, linear programming & ott
# 332                               vice president, dfir
# 343  associate vice president, infrastructure & pro...
# 348                   vice president, integrated media
# 373                                  v.p. of marketing
# 381                 sr. director of marketing, imaging
# 396                     market research senior manager
# 405           vice president - chief diversity officer
# 421  vp group director content and communications p...
#
#                                           company_name  \
# 9                                        truecar, inc.
# 11                                                hulu
# 12                    sony pictures entertainment inc.
# 17                                         cybercoders
# 18                    research & development institute
# 19                                   the weinman group
# 26                                             taboola
# 27                         the boston consulting group
# 28                                          riot games
# 30                                       prn ambulance
# 41                                          clicktripz
# 42                            sinclair broadcast group
# 44                           the aerospace corporation
# 49                         pacific reproductive center
# 65                       amphastar pharmaceuticals inc
# 69                            new sun investment group
# 94                                                  lt
# 95                                              boeing
# 105                                     veear projects
# 106                                        cybercoders
# 117                               bcg digital ventures
# 118                                             acorns
# 119                                           experian
# 162                                            system1
# 175                                  kaiser permanente
# 191                                    landmark health
# 193                                           experian
# 211                                           workcare
# 216                      downtown women's center, inc.
# 222  southern california university of health sciences
# 232                                               hulu
# 245                                        cybercoders
# 269                                          caloptima
# 271                                    landmark health
# 294                         tadashi shoji & associates
# 300                                            joybird
# 310                                             gumgum
# 329                                  shield healthcare
# 330                                        jukin media
# 332                    stroz friedberg, an aon company
# 343                        california state university
# 348                                   ocean media, llc
# 373                         coaster company of america
# 381                                          kavo kerr
# 396                                      capital group
# 405                           azusa pacific university
# 421                                           innocean
#
#                        location  \
# 9              santa monica, ca
# 11             santa monica, ca
# 12        culver city, ca 90232
# 17     west hollywood, ca 90038
# 18           van nuys, ca 91406
# 19              los angeles, ca
# 26              los angeles, ca
# 27              los angeles, ca
# 28              los angeles, ca
# 30              north hills, ca
# 41          manhattan beach, ca
# 42             santa monica, ca
# 44         el segundo, ca 90245
# 49             irvine, ca 92618
# 65         rancho cucamonga, ca
# 69           commerce, ca 90040
# 94              los angeles, ca
# 95         el segundo, ca 90245
# 105             los angeles, ca
# 106            venice, ca 90291
# 117         manhattan beach, ca
# 118                  irvine, ca
# 119              costa mesa, ca
# 162                  venice, ca
# 175                pasadena, ca
# 191        huntington beach, ca
# 193              costa mesa, ca
# 211           anaheim, ca 92805
# 216             los angeles, ca
# 222                whittier, ca
# 232            santa monica, ca
# 245       culver city, ca 90230
# 269                  orange, ca
# 271  huntington beach, ca 92615
# 294                commerce, ca
# 300                commerce, ca
# 310            santa monica, ca
# 329          valencia, ca 91355
# 330             los angeles, ca
# 332             los angeles, ca
# 343               dominguez, ca
# 348  huntington beach, ca 92647
# 373        santa fe springs, ca
# 381               santa ana, ca
# 396       los angeles, ca 90071
# 405                   azusa, ca
# 421        huntington beach, ca
#
#                                                summary  \
# 9    this team member will create transparency for ...
# 11   we are looking for data scientists who are pas...
# 12   must have experience with big data and standar...
# 17   data scientist are you a data scientist with a...
# 18   we are seeking a lab scientist to manage all o...
# 19   the role is more risk professional with advanc...
# 26   experience in collecting data from/exposing da...
# 27   big data engineers, together with data scienti...
# 28   work closely with fellow data scientists and e...
# 30   the data analysis specialist is responsible fo...
# 41   clicktripz is looking for a skilled data scien...
# 42   aid in analysis and storytelling using qualita...
# 44   experience in data science projects. experienc...
# 49   monitors and is accountable for test data, qua...
# 65   coordinate organizational resources to support...
# 69   manage and resolve the key data issues involvi...
# 94   the ideal candidate for this senior data scien...
# 95   locate critical data in department/program lib...
# 105  our client is seeking for sr.data scientist in...
# 106  senior data engineer / architect if you consid...
# 117  big data and fast data (i.e.:. build innovativ...
# 118  senior data scientist - informational intellig...
# 119  experience analyzing large data set in order t...
# 162  manage roadmap and requirements for data wareh...
# 175  responsible for project related training, supe...
# 191  develop tools for monitoring data quality and ...
# 193  minimum of 10 years of data analysis experienc...
# 211  the ability to gather data, compile informatio...
# 216  in good standing with the board of behavioral ...
# 222  collects and researches data; leads university...
# 232  consult with key stakeholders to help them use...
# 245  director of analytics do you have 10+ yrs in a...
# 269  quality management, quality analytics and dise...
# 271  overview director of healthcare economics & an...
# 294  tadashi shoji, an la-based fashion house, is s...
# 300  be a key partner across all growth marketing-r...
# 310  experience with sports commercial rights & sal...
# 329  we have an immediate opening in our valencia, ...
# 330  the vice president, linear programming & ott m...
# 332  as a vice president, you will manage local and...
# 343  the vice president / cio provides overall mana...
# 348  the vice president, integrated media role will...
# 373  - high technical and experience in big data, a...
# 381  reporting to the vice president, north america...
# 396  this position will report to the vice presiden...
# 405  vice president - chief diversity officer. azus...
# 421  working with data science and media teams, mea...
#
#                          salary
# 9                 Nothing_found
# 11                Nothing_found
# 12                Nothing_found
# 17   $100,000 - $250,000 a year
# 18     $35,000 - $40,000 a year
# 19                Nothing_found
# 26                Nothing_found
# 27                Nothing_found
# 28                Nothing_found
# 30                Nothing_found
# 41                Nothing_found
# 42                Nothing_found
# 44                Nothing_found
# 49                Nothing_found
# 65                Nothing_found
# 69                Nothing_found
# 94   $150,000 - $190,000 a year
# 95                Nothing_found
# 105               Nothing_found
# 106  $150,000 - $200,000 a year
# 117               Nothing_found
# 118               Nothing_found
# 119               Nothing_found
# 162               Nothing_found
# 175               Nothing_found
# 191               Nothing_found
# 193               Nothing_found
# 211               Nothing_found
# 216               Nothing_found
# 222               Nothing_found
# 232               Nothing_found
# 245  $100,000 - $200,000 a year
# 269               Nothing_found
# 271               Nothing_found
# 294               Nothing_found
# 300               Nothing_found
# 310               Nothing_found
# 329               Nothing_found
# 330               Nothing_found
# 332               Nothing_found
# 343               Nothing_found
# 348               Nothing_found
# 373               Nothing_found
# 381               Nothing_found
# 396               Nothing_found
# 405               Nothing_found
# 421               Nothing_found

# %% [markdown]
# ## Dropping unwanted job titles

# %%
#Try this
sample_df = sample_df[(sample_df["job_title"] != "account") & 
                       (~sample_df["job_title"].str.contains('engineer')) &
                      (~sample_df["job_title"].str.contains('research')) &
                     (~sample_df["job_title"].str.contains('manager')) &
                      (~sample_df["job_title"].str.contains('developer')) & 
                        (~sample_df["job_title"].str.contains('vice president of sales')) & 
                        (~sample_df["job_title"].str.contains('communications')) & 
                    (~sample_df["job_title"].str.contains('client')) & 
                     (~sample_df["job_title"].str.contains('analyst'))]






sample_df
# Out:
#                                              job_title  \
# 11                                      data scientist
# 12                                      data scientist
# 17                                      data scientist
# 19   operational risk reporting and metrics specialist
# 26                                      data scientist
# 28                                      data scientist
# 30                            data analysis specialist
# 41                                      data scientist
# 44                    signal processing data scientist
# 49                       clinical laboratory scientist
# 94                               senior data scientist
# 105                                 sr. data scientist
# 117                              senior data scientist
# 118  senior data scientist - informational intellig...
# 119                              data scientist senior
# 175                         health data project leader
# 191  senior healthcare economics consultant (remote...
# 193                                 analytics director
# 211                   director, information technology
# 216           director of permanent supportive housing
# 222        dean, office of institutional effectiveness
# 232                         director, people analytics
# 245                              director of analytics
# 269              executive director, quality analytics
# 271       director of healthcare economics & analytics
# 294                                      director of e
# 300                       director of growth marketing
# 329                                       vp marketing
# 330                       vp, linear programming & ott
# 332                               vice president, dfir
# 343  associate vice president, infrastructure & pro...
# 348                   vice president, integrated media
# 373                                  v.p. of marketing
# 381                 sr. director of marketing, imaging
# 405           vice president - chief diversity officer
#
#                                           company_name  \
# 11                                                hulu
# 12                    sony pictures entertainment inc.
# 17                                         cybercoders
# 19                                   the weinman group
# 26                                             taboola
# 28                                          riot games
# 30                                       prn ambulance
# 41                                          clicktripz
# 44                           the aerospace corporation
# 49                         pacific reproductive center
# 94                                                  lt
# 105                                     veear projects
# 117                               bcg digital ventures
# 118                                             acorns
# 119                                           experian
# 175                                  kaiser permanente
# 191                                    landmark health
# 193                                           experian
# 211                                           workcare
# 216                      downtown women's center, inc.
# 222  southern california university of health sciences
# 232                                               hulu
# 245                                        cybercoders
# 269                                          caloptima
# 271                                    landmark health
# 294                         tadashi shoji & associates
# 300                                            joybird
# 329                                  shield healthcare
# 330                                        jukin media
# 332                    stroz friedberg, an aon company
# 343                        california state university
# 348                                   ocean media, llc
# 373                         coaster company of america
# 381                                          kavo kerr
# 405                           azusa pacific university
#
#                        location  \
# 11             santa monica, ca
# 12        culver city, ca 90232
# 17     west hollywood, ca 90038
# 19              los angeles, ca
# 26              los angeles, ca
# 28              los angeles, ca
# 30              north hills, ca
# 41          manhattan beach, ca
# 44         el segundo, ca 90245
# 49             irvine, ca 92618
# 94              los angeles, ca
# 105             los angeles, ca
# 117         manhattan beach, ca
# 118                  irvine, ca
# 119              costa mesa, ca
# 175                pasadena, ca
# 191        huntington beach, ca
# 193              costa mesa, ca
# 211           anaheim, ca 92805
# 216             los angeles, ca
# 222                whittier, ca
# 232            santa monica, ca
# 245       culver city, ca 90230
# 269                  orange, ca
# 271  huntington beach, ca 92615
# 294                commerce, ca
# 300                commerce, ca
# 329          valencia, ca 91355
# 330             los angeles, ca
# 332             los angeles, ca
# 343               dominguez, ca
# 348  huntington beach, ca 92647
# 373        santa fe springs, ca
# 381               santa ana, ca
# 405                   azusa, ca
#
#                                                summary  \
# 11   we are looking for data scientists who are pas...
# 12   must have experience with big data and standar...
# 17   data scientist are you a data scientist with a...
# 19   the role is more risk professional with advanc...
# 26   experience in collecting data from/exposing da...
# 28   work closely with fellow data scientists and e...
# 30   the data analysis specialist is responsible fo...
# 41   clicktripz is looking for a skilled data scien...
# 44   experience in data science projects. experienc...
# 49   monitors and is accountable for test data, qua...
# 94   the ideal candidate for this senior data scien...
# 105  our client is seeking for sr.data scientist in...
# 117  big data and fast data (i.e.:. build innovativ...
# 118  senior data scientist - informational intellig...
# 119  experience analyzing large data set in order t...
# 175  responsible for project related training, supe...
# 191  develop tools for monitoring data quality and ...
# 193  minimum of 10 years of data analysis experienc...
# 211  the ability to gather data, compile informatio...
# 216  in good standing with the board of behavioral ...
# 222  collects and researches data; leads university...
# 232  consult with key stakeholders to help them use...
# 245  director of analytics do you have 10+ yrs in a...
# 269  quality management, quality analytics and dise...
# 271  overview director of healthcare economics & an...
# 294  tadashi shoji, an la-based fashion house, is s...
# 300  be a key partner across all growth marketing-r...
# 329  we have an immediate opening in our valencia, ...
# 330  the vice president, linear programming & ott m...
# 332  as a vice president, you will manage local and...
# 343  the vice president / cio provides overall mana...
# 348  the vice president, integrated media role will...
# 373  - high technical and experience in big data, a...
# 381  reporting to the vice president, north america...
# 405  vice president - chief diversity officer. azus...
#
#                          salary
# 11                Nothing_found
# 12                Nothing_found
# 17   $100,000 - $250,000 a year
# 19                Nothing_found
# 26                Nothing_found
# 28                Nothing_found
# 30                Nothing_found
# 41                Nothing_found
# 44                Nothing_found
# 49                Nothing_found
# 94   $150,000 - $190,000 a year
# 105               Nothing_found
# 117               Nothing_found
# 118               Nothing_found
# 119               Nothing_found
# 175               Nothing_found
# 191               Nothing_found
# 193               Nothing_found
# 211               Nothing_found
# 216               Nothing_found
# 222               Nothing_found
# 232               Nothing_found
# 245  $100,000 - $200,000 a year
# 269               Nothing_found
# 271               Nothing_found
# 294               Nothing_found
# 300               Nothing_found
# 329               Nothing_found
# 330               Nothing_found
# 332               Nothing_found
# 343               Nothing_found
# 348               Nothing_found
# 373               Nothing_found
# 381               Nothing_found
# 405               Nothing_found

# %% [markdown]
# ## Dropping Unwanted Cities

# %%
sample_df = sample_df[ (~sample_df["location"].str.contains('woodland hills')) &
                      (~sample_df["location"].str.contains('santa monica')) &
                      (~sample_df["location"].str.contains('culver city')) &
                      (~sample_df["location"].str.contains('burbank')) &
                      (~sample_df["location"].str.contains('hollywood')) &
                      (~sample_df["location"].str.contains('westwood')) &
                      (~sample_df["location"].str.contains('universal city')) &
                      (~sample_df["location"].str.contains('beverly hills')) &
                      (~sample_df["location"].str.contains('playa vista')) &
                      (~sample_df["location"].str.contains('valencia')) &
                      (~sample_df["location"].str.contains('encino')) &
                      (~sample_df["location"].str.contains('venice'))
                     ]



sample_df
# Out:
#                                              job_title  \
# 19   operational risk reporting and metrics specialist
# 26                                      data scientist
# 28                                      data scientist
# 30                            data analysis specialist
# 41                                      data scientist
# 44                    signal processing data scientist
# 49                       clinical laboratory scientist
# 94                               senior data scientist
# 105                                 sr. data scientist
# 117                              senior data scientist
# 118  senior data scientist - informational intellig...
# 119                              data scientist senior
# 175                         health data project leader
# 191  senior healthcare economics consultant (remote...
# 193                                 analytics director
# 211                   director, information technology
# 216           director of permanent supportive housing
# 222        dean, office of institutional effectiveness
# 269              executive director, quality analytics
# 271       director of healthcare economics & analytics
# 294                                      director of e
# 300                       director of growth marketing
# 330                       vp, linear programming & ott
# 332                               vice president, dfir
# 343  associate vice president, infrastructure & pro...
# 348                   vice president, integrated media
# 373                                  v.p. of marketing
# 381                 sr. director of marketing, imaging
# 405           vice president - chief diversity officer
#
#                                           company_name  \
# 19                                   the weinman group
# 26                                             taboola
# 28                                          riot games
# 30                                       prn ambulance
# 41                                          clicktripz
# 44                           the aerospace corporation
# 49                         pacific reproductive center
# 94                                                  lt
# 105                                     veear projects
# 117                               bcg digital ventures
# 118                                             acorns
# 119                                           experian
# 175                                  kaiser permanente
# 191                                    landmark health
# 193                                           experian
# 211                                           workcare
# 216                      downtown women's center, inc.
# 222  southern california university of health sciences
# 269                                          caloptima
# 271                                    landmark health
# 294                         tadashi shoji & associates
# 300                                            joybird
# 330                                        jukin media
# 332                    stroz friedberg, an aon company
# 343                        california state university
# 348                                   ocean media, llc
# 373                         coaster company of america
# 381                                          kavo kerr
# 405                           azusa pacific university
#
#                        location  \
# 19              los angeles, ca
# 26              los angeles, ca
# 28              los angeles, ca
# 30              north hills, ca
# 41          manhattan beach, ca
# 44         el segundo, ca 90245
# 49             irvine, ca 92618
# 94              los angeles, ca
# 105             los angeles, ca
# 117         manhattan beach, ca
# 118                  irvine, ca
# 119              costa mesa, ca
# 175                pasadena, ca
# 191        huntington beach, ca
# 193              costa mesa, ca
# 211           anaheim, ca 92805
# 216             los angeles, ca
# 222                whittier, ca
# 269                  orange, ca
# 271  huntington beach, ca 92615
# 294                commerce, ca
# 300                commerce, ca
# 330             los angeles, ca
# 332             los angeles, ca
# 343               dominguez, ca
# 348  huntington beach, ca 92647
# 373        santa fe springs, ca
# 381               santa ana, ca
# 405                   azusa, ca
#
#                                                summary  \
# 19   the role is more risk professional with advanc...
# 26   experience in collecting data from/exposing da...
# 28   work closely with fellow data scientists and e...
# 30   the data analysis specialist is responsible fo...
# 41   clicktripz is looking for a skilled data scien...
# 44   experience in data science projects. experienc...
# 49   monitors and is accountable for test data, qua...
# 94   the ideal candidate for this senior data scien...
# 105  our client is seeking for sr.data scientist in...
# 117  big data and fast data (i.e.:. build innovativ...
# 118  senior data scientist - informational intellig...
# 119  experience analyzing large data set in order t...
# 175  responsible for project related training, supe...
# 191  develop tools for monitoring data quality and ...
# 193  minimum of 10 years of data analysis experienc...
# 211  the ability to gather data, compile informatio...
# 216  in good standing with the board of behavioral ...
# 222  collects and researches data; leads university...
# 269  quality management, quality analytics and dise...
# 271  overview director of healthcare economics & an...
# 294  tadashi shoji, an la-based fashion house, is s...
# 300  be a key partner across all growth marketing-r...
# 330  the vice president, linear programming & ott m...
# 332  as a vice president, you will manage local and...
# 343  the vice president / cio provides overall mana...
# 348  the vice president, integrated media role will...
# 373  - high technical and experience in big data, a...
# 381  reporting to the vice president, north america...
# 405  vice president - chief diversity officer. azus...
#
#                          salary
# 19                Nothing_found
# 26                Nothing_found
# 28                Nothing_found
# 30                Nothing_found
# 41                Nothing_found
# 44                Nothing_found
# 49                Nothing_found
# 94   $150,000 - $190,000 a year
# 105               Nothing_found
# 117               Nothing_found
# 118               Nothing_found
# 119               Nothing_found
# 175               Nothing_found
# 191               Nothing_found
# 193               Nothing_found
# 211               Nothing_found
# 216               Nothing_found
# 222               Nothing_found
# 269               Nothing_found
# 271               Nothing_found
# 294               Nothing_found
# 300               Nothing_found
# 330               Nothing_found
# 332               Nothing_found
# 343               Nothing_found
# 348               Nothing_found
# 373               Nothing_found
# 381               Nothing_found
# 405               Nothing_found

# %% [markdown]
# ## Dropping Companies

# %%
sample_df = sample_df[ (~sample_df["company_name"].str.contains('ucla Extension')) &
                      (~sample_df["company_name"].str.contains('usc')) &
                      (~sample_df["company_name"].str.contains('health')) &
                      (~sample_df["company_name"].str.contains('riot games')) &
                      (~sample_df["company_name"].str.contains('los angeles county')) &
                      (~sample_df["company_name"].str.contains('lieberman research worldwide')) &
                      (~sample_df["company_name"].str.contains('hospital')) &
                      (~sample_df["company_name"].str.contains('medicine')) &
                       (~sample_df["company_name"].str.contains('university')) &
                      (~sample_df["company_name"].str.contains('first 5 la'))  
                     ]

sample_df
# Out:
#                                              job_title  \
# 19   operational risk reporting and metrics specialist
# 26                                      data scientist
# 30                            data analysis specialist
# 41                                      data scientist
# 44                    signal processing data scientist
# 49                       clinical laboratory scientist
# 94                               senior data scientist
# 105                                 sr. data scientist
# 117                              senior data scientist
# 118  senior data scientist - informational intellig...
# 119                              data scientist senior
# 175                         health data project leader
# 193                                 analytics director
# 211                   director, information technology
# 216           director of permanent supportive housing
# 269              executive director, quality analytics
# 294                                      director of e
# 300                       director of growth marketing
# 330                       vp, linear programming & ott
# 332                               vice president, dfir
# 348                   vice president, integrated media
# 373                                  v.p. of marketing
# 381                 sr. director of marketing, imaging
#
#                         company_name                    location  \
# 19                 the weinman group             los angeles, ca
# 26                           taboola             los angeles, ca
# 30                     prn ambulance             north hills, ca
# 41                        clicktripz         manhattan beach, ca
# 44         the aerospace corporation        el segundo, ca 90245
# 49       pacific reproductive center            irvine, ca 92618
# 94                                lt             los angeles, ca
# 105                   veear projects             los angeles, ca
# 117             bcg digital ventures         manhattan beach, ca
# 118                           acorns                  irvine, ca
# 119                         experian              costa mesa, ca
# 175                kaiser permanente                pasadena, ca
# 193                         experian              costa mesa, ca
# 211                         workcare           anaheim, ca 92805
# 216    downtown women's center, inc.             los angeles, ca
# 269                        caloptima                  orange, ca
# 294       tadashi shoji & associates                commerce, ca
# 300                          joybird                commerce, ca
# 330                      jukin media             los angeles, ca
# 332  stroz friedberg, an aon company             los angeles, ca
# 348                 ocean media, llc  huntington beach, ca 92647
# 373       coaster company of america        santa fe springs, ca
# 381                        kavo kerr               santa ana, ca
#
#                                                summary  \
# 19   the role is more risk professional with advanc...
# 26   experience in collecting data from/exposing da...
# 30   the data analysis specialist is responsible fo...
# 41   clicktripz is looking for a skilled data scien...
# 44   experience in data science projects. experienc...
# 49   monitors and is accountable for test data, qua...
# 94   the ideal candidate for this senior data scien...
# 105  our client is seeking for sr.data scientist in...
# 117  big data and fast data (i.e.:. build innovativ...
# 118  senior data scientist - informational intellig...
# 119  experience analyzing large data set in order t...
# 175  responsible for project related training, supe...
# 193  minimum of 10 years of data analysis experienc...
# 211  the ability to gather data, compile informatio...
# 216  in good standing with the board of behavioral ...
# 269  quality management, quality analytics and dise...
# 294  tadashi shoji, an la-based fashion house, is s...
# 300  be a key partner across all growth marketing-r...
# 330  the vice president, linear programming & ott m...
# 332  as a vice president, you will manage local and...
# 348  the vice president, integrated media role will...
# 373  - high technical and experience in big data, a...
# 381  reporting to the vice president, north america...
#
#                          salary
# 19                Nothing_found
# 26                Nothing_found
# 30                Nothing_found
# 41                Nothing_found
# 44                Nothing_found
# 49                Nothing_found
# 94   $150,000 - $190,000 a year
# 105               Nothing_found
# 117               Nothing_found
# 118               Nothing_found
# 119               Nothing_found
# 175               Nothing_found
# 193               Nothing_found
# 211               Nothing_found
# 216               Nothing_found
# 269               Nothing_found
# 294               Nothing_found
# 300               Nothing_found
# 330               Nothing_found
# 332               Nothing_found
# 348               Nothing_found
# 373               Nothing_found
# 381               Nothing_found

# %%
sample_df.to_csv(project_path + "2_data/2_clean/scraper_indeed_jobs_clean.csv", encoding='utf-8')

# %% [markdown]
# ### Saving Clean Data

# %% [markdown]
# ## Calculating Distance

# %%
sample_df["clean_address"] = sample_df["company_name"] + ' ' + sample_df["location"]

# %%
commutes = []

for address in sample_df["clean_address"]:
    from_address = "10757 Longworth Ave Santa Fe Springs CA 90670"
    region = 'US'
    try:
        to_address = address
        route = WazeRouteCalculator.WazeRouteCalculator(from_address, to_address, region )
        commutes.append(route.calc_route_info(real_time=False))
    except:
        commutes.append((0,0))
# Out:
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: the weinman group los angeles, ca
# Time 44.55 minutes, distance 46.02 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: taboola los angeles, ca
# Time 44.55 minutes, distance 46.02 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: prn ambulance north hills, ca
# Time 47.88 minutes, distance 65.49 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: clicktripz manhattan beach, ca
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: the aerospace corporation el segundo, ca 90245
# Time 28.67 minutes, distance 38.10 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: pacific reproductive center irvine, ca 92618
# Time 31.60 minutes, distance 43.91 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: lt los angeles, ca
# Time 44.88 minutes, distance 46.01 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: veear projects los angeles, ca
# Time 19.75 minutes, distance 19.53 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: bcg digital ventures manhattan beach, ca
# Time 26.45 minutes, distance 34.99 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: acorns irvine, ca
# Time 34.28 minutes, distance 46.38 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: experian costa mesa, ca
# Time 30.58 minutes, distance 44.78 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: kaiser permanente pasadena, ca
# Time 31.03 minutes, distance 45.12 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: experian costa mesa, ca
# Time 30.58 minutes, distance 44.78 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: workcare anaheim, ca 92805
# Time 23.32 minutes, distance 30.16 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: downtown women's center, inc. los angeles, ca
# Time 22.33 minutes, distance 22.60 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: caloptima orange, ca
# Time 27.15 minutes, distance 37.30 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: tadashi shoji & associates commerce, ca
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: joybird commerce, ca
# Time 13.07 minutes, distance 11.91 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: jukin media los angeles, ca
# Time 29.92 minutes, distance 34.80 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: stroz friedberg, an aon company los angeles, ca
# Time 31.20 minutes, distance 27.81 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: ocean media, llc huntington beach, ca 92647
# Time 30.10 minutes, distance 36.24 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: coaster company of america santa fe springs, ca
# Time 6.63 minutes, distance 5.51 km.
# From: 10757 Longworth Ave Santa Fe Springs CA 90670 - to: kavo kerr santa ana, ca
# Time 31.90 minutes, distance 35.73 km.

# %%
df = pd.DataFrame(commutes) 
df.columns = ['commute', 'distance_km']
df.index = range(1,len(df)+1)
sample_df = sample_df.join(df, lsuffix='_caller', rsuffix='_other')
sample_df
# Out:
#                                              job_title  \
# 19   operational risk reporting and metrics specialist
# 26                                      data scientist
# 30                            data analysis specialist
# 41                                      data scientist
# 44                    signal processing data scientist
# 49                       clinical laboratory scientist
# 94                               senior data scientist
# 105                                 sr. data scientist
# 117                              senior data scientist
# 118  senior data scientist - informational intellig...
# 119                              data scientist senior
# 175                         health data project leader
# 193                                 analytics director
# 211                   director, information technology
# 216           director of permanent supportive housing
# 269              executive director, quality analytics
# 294                                      director of e
# 300                       director of growth marketing
# 330                       vp, linear programming & ott
# 332                               vice president, dfir
# 348                   vice president, integrated media
# 373                                  v.p. of marketing
# 381                 sr. director of marketing, imaging
#
#                         company_name                    location  \
# 19                 the weinman group             los angeles, ca
# 26                           taboola             los angeles, ca
# 30                     prn ambulance             north hills, ca
# 41                        clicktripz         manhattan beach, ca
# 44         the aerospace corporation        el segundo, ca 90245
# 49       pacific reproductive center            irvine, ca 92618
# 94                                lt             los angeles, ca
# 105                   veear projects             los angeles, ca
# 117             bcg digital ventures         manhattan beach, ca
# 118                           acorns                  irvine, ca
# 119                         experian              costa mesa, ca
# 175                kaiser permanente                pasadena, ca
# 193                         experian              costa mesa, ca
# 211                         workcare           anaheim, ca 92805
# 216    downtown women's center, inc.             los angeles, ca
# 269                        caloptima                  orange, ca
# 294       tadashi shoji & associates                commerce, ca
# 300                          joybird                commerce, ca
# 330                      jukin media             los angeles, ca
# 332  stroz friedberg, an aon company             los angeles, ca
# 348                 ocean media, llc  huntington beach, ca 92647
# 373       coaster company of america        santa fe springs, ca
# 381                        kavo kerr               santa ana, ca
#
#                                                summary  \
# 19   the role is more risk professional with advanc...
# 26   experience in collecting data from/exposing da...
# 30   the data analysis specialist is responsible fo...
# 41   clicktripz is looking for a skilled data scien...
# 44   experience in data science projects. experienc...
# 49   monitors and is accountable for test data, qua...
# 94   the ideal candidate for this senior data scien...
# 105  our client is seeking for sr.data scientist in...
# 117  big data and fast data (i.e.:. build innovativ...
# 118  senior data scientist - informational intellig...
# 119  experience analyzing large data set in order t...
# 175  responsible for project related training, supe...
# 193  minimum of 10 years of data analysis experienc...
# 211  the ability to gather data, compile informatio...
# 216  in good standing with the board of behavioral ...
# 269  quality management, quality analytics and dise...
# 294  tadashi shoji, an la-based fashion house, is s...
# 300  be a key partner across all growth marketing-r...
# 330  the vice president, linear programming & ott m...
# 332  as a vice president, you will manage local and...
# 348  the vice president, integrated media role will...
# 373  - high technical and experience in big data, a...
# 381  reporting to the vice president, north america...
#
#                          salary  \
# 19                Nothing_found
# 26                Nothing_found
# 30                Nothing_found
# 41                Nothing_found
# 44                Nothing_found
# 49                Nothing_found
# 94   $150,000 - $190,000 a year
# 105               Nothing_found
# 117               Nothing_found
# 118               Nothing_found
# 119               Nothing_found
# 175               Nothing_found
# 193               Nothing_found
# 211               Nothing_found
# 216               Nothing_found
# 269               Nothing_found
# 294               Nothing_found
# 300               Nothing_found
# 330               Nothing_found
# 332               Nothing_found
# 348               Nothing_found
# 373               Nothing_found
# 381               Nothing_found
#
#                                        clean_address    commute  distance_km
# 19                 the weinman group los angeles, ca  29.916667       34.803
# 26                           taboola los angeles, ca        NaN          NaN
# 30                     prn ambulance north hills, ca        NaN          NaN
# 41                    clicktripz manhattan beach, ca        NaN          NaN
# 44    the aerospace corporation el segundo, ca 90245        NaN          NaN
# 49      pacific reproductive center irvine, ca 92618        NaN          NaN
# 94                                lt los angeles, ca        NaN          NaN
# 105                   veear projects los angeles, ca        NaN          NaN
# 117         bcg digital ventures manhattan beach, ca        NaN          NaN
# 118                                acorns irvine, ca        NaN          NaN
# 119                          experian costa mesa, ca        NaN          NaN
# 175                   kaiser permanente pasadena, ca        NaN          NaN
# 193                          experian costa mesa, ca        NaN          NaN
# 211                       workcare anaheim, ca 92805        NaN          NaN
# 216    downtown women's center, inc. los angeles, ca        NaN          NaN
# 269                             caloptima orange, ca        NaN          NaN
# 294          tadashi shoji & associates commerce, ca        NaN          NaN
# 300                             joybird commerce, ca        NaN          NaN
# 330                      jukin media los angeles, ca        NaN          NaN
# 332  stroz friedberg, an aon company los angeles, ca        NaN          NaN
# 348      ocean media, llc huntington beach, ca 92647        NaN          NaN
# 373  coaster company of america santa fe springs, ca        NaN          NaN
# 381                          kavo kerr santa ana, ca        NaN          NaN

# %% [markdown]
# ### Filtering Based on Distance

# %%
sample_df.to_csv(project_path + "2_data/2_clean/scraper_indeed_jobs_clean_enhanced.csv", encoding='utf-8')
